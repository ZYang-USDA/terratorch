# %% [markdown]
# ### Setup for Google Colab
#
# If you are running this notebook in Google Colab, complete the following steps:
#
# 1. In Colab, we recommend going to **Runtime → Change runtime type** and selecting **T4 GPU**
# 2. Install **TerraTorch** and the required packages
# 3. Download the dataset (as part of the notebook)

# %%
# !pip install terratorch==1.2.1
# !pip install gdown tensorboard
# !pip install -U jupyter ipywidgets

# %% [markdown]
# ------------
#
# ## Notebook: Temporal Wrapper

# %% [markdown]
# These examples demonstrate how to use the `TemporalWrapper` to process temporal inputs with a non-temporal backbone (e.g., TerraMind). They show how to integrate the TemporalWrapper into TerraTorch encoder–decoder pipelines and explain three pooling methods: `mean`, `concat`, and `diff`.
#
# Each pooling method can operate directly on the temporal dimension or after subset-based averaging using `subset_lengths`; the `diff` example below illustrates this in practice.
#
# See full documentation here: [TemporalWrapper — TerraTorch](https://ibm.github.io/terratorch/stable/guide/temporal_wrapper/)

# %% [markdown]
# ## Data
#
# We download a subset of a temporal crop dataset and build a TerraTorch Dataloader.

# %%
import gdown
import os

# Download a random subset for demos (~1 GB)
if not os.path.isfile('multi-temporal-crop-classification-subset.tar.gz'):
    gdown.download("https://drive.google.com/uc?id=1SycflNslu47yfMg2i_z8FqYkhZQv7JQM")

if not os.path.isdir('multi-temporal-crop-classification-subset/'):
    # !tar -xzvf multi-temporal-crop-classification-subset.tar.gz

dataset_path = "multi-temporal-crop-classification-subset"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1SycflNslu47yfMg2i_z8FqYkhZQv7JQM
# From (redirected): https://drive.google.com/uc?id=1SycflNslu47yfMg2i_z8FqYkhZQv7JQM&confirm=t&uuid=15d93e25-7f0c-407f-8c12-51233404c5ef
# To: /Users/isw/Documents/1_Embed2Scale/Embedding_Benchmarking/terratorch/examples/multitemporal_data/multi-temporal-crop-classification-subset.tar.gz
# 100%|██████████████████████████████████████████████████████████████| 1.09G/1.09G [01:28<00:00, 12.4MB/s]
# x multi-temporal-crop-classification-subset/
# x multi-temporal-crop-classification-subset/.DS_Store
# x multi-temporal-crop-classification-subset/training_chips/
# x multi-temporal-crop-classification-subset/validation_chips/
# x multi-temporal-crop-classification-subset/training_data.txt
# x multi-temporal-crop-classification-subset/validation_data.txt
# x multi-temporal-crop-classification-subset/validation_chips/chip_126_446.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_236_335.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_127_427.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_316_522_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_131_428.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_123_447_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_233_297_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_270_263.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_250_258.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_128_445.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_242_597_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_239_356.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_131_428_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_368_344.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_231_274.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_332_332_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_251_583_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_034_146.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_313_475_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_304_528.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_126_506.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_034_147.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_249_449_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_347_343_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_128_445_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_243_270.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_320_314_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_234_289.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_227_292_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_126_303.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_124_303_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_226_335_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_330_516_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_237_449_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_335_498_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_227_283_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_236_445.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_239_476_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_033_196.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_268_324.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_236_273_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_052_247.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_131_422.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_225_326_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_270_263_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_331_527.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_229_272.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_232_294.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_230_311_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_359_558_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_328_498.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_127_427_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_228_280.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_236_332_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_052_043_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_049_232.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_233_283.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_024_087.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_125_502.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_316_522.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_039_109.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_420_326.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_124_439_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_239_363.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_244_593.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_127_491_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_224_489_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_054_201_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_228_330_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_328_498_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_057_195_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_129_499_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_126_491_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_330_513.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_232_279_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_225_335.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_329_511_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_245_592_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_129_480_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_314_518.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_228_297_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_347_343.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_306_527.mask.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_248_444_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips/chip_234_292_merged.tif
# x multi-temporal-crop-classification-subset/validation_chips
merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_134_499.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_145_338_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_140_484_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_251_585_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_133_498.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_143_479_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_126_307.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_248_586.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_235_445.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_135_316_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_235_444.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_137_309.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_277_252_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_126_357_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_135_321_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_237_442_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_235_440_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_025_082.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_280_560_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_137_476_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_139_488.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_126_479_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_280_251.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_273_470.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_132_508.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_135_401.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_328_510.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_252_261_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_126_133_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_144_498.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_134_316_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_250_585_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_276_565_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_274_408_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_141_484_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_132_302_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_127_477.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_136_478.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_326_517_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_126_307_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_127_483_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_329_493_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_135_324_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_236_289.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_134_497_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_135_471_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_252_266.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_010_063.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_022_126.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_131_507.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_329_393_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_131_506.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_421_326_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_251_425.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_134_484.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_234_445_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_137_495_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_236_369_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_139_437_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_134_423.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_251_418_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_251_259_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_127_127_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_277_403.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_132_438_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_136_276_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_233_597.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_138_495_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_139_473_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_274_467_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_142_474_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_136_437_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_234_354_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_132_443.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_250_588_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_142_443_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_234_444.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_126_502_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_234_445.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_421_329.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_251_485_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_234_376.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_234_288_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_237_334_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_249_587.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_133_443_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_248_590.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_279_265_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_248_591.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_127_442.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_137_498_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_127_471_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_126_497_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_127_446_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_136_276.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_132_507_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_276_402_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_125_481.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_140_411_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_138_494.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_138_495.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_142_485.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_142_497_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_422_327.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_249_587_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_135_434.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_137_432_merged.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_143_476.mask.tif
# x multi-temporal-crop-classification-subset/training_chips/chip_139_390_merged.tif

# %%
# !ls "{dataset_path}"

# %%
import os
import sys
import torch
import gdown
import terratorch
import albumentations
import lightning.pytorch as pl
import matplotlib.pyplot as plt
from terratorch.datamodules import MultiTemporalCropClassificationDataModule
from terratorch.tasks import SemanticSegmentationTask
import warnings
warnings.filterwarnings('ignore')

# Adjusted dataset class for this dataset (general dataset could be used as well)
datamodule = MultiTemporalCropClassificationDataModule(
    batch_size=8,
    num_workers=2,
    data_root=dataset_path,
    train_transform=[
        terratorch.datasets.transforms.FlattenTemporalIntoChannels(),  # Required for temporal data
        albumentations.D4(), # Random flips and rotation
        albumentations.pytorch.transforms.ToTensorV2(),
        terratorch.datasets.transforms.UnflattenTemporalFromChannels(n_timesteps=3),
    ],
    val_transform=None,  # Using ToTensor() by default
    test_transform=None,
    expand_temporal_dimension=True,
    use_metadata=False, # The crop dataset has metadata for location and time
    reduce_zero_label=True,
)

# Setup train and val datasets
datamodule.setup("fit")

# %%
train_dataset = datamodule.train_dataset
len(train_dataset)

# %%
# plotting a few samples
for i in range(5):
    train_dataset.plot(train_dataset[i])

# %% [markdown]
# ## Integrating the Temporal Wrapper

# %% [markdown]
# ### Wrapping a backbone
#
# The `TemporalWrapper` can be combined with any TerraTorch backbone by wrapping it as shown below. It can also be directly integrated into encoder–decoder pipelines, which we illustrate next through three example setups (Option 1-3).

# %%
from terratorch.registry import BACKBONE_REGISTRY
from terratorch.models.utils import TemporalWrapper

backbone = BACKBONE_REGISTRY.build(
    "terramind_v1_small",
    modalities=["S2L2A"],
    pretrained=True,
)

temporal_backbone = TemporalWrapper(backbone, pooling="mean")

temporal_backbone
# Out:
# 2025-12-19 15:09:28,497 - INFO - HTTP Request: HEAD https://huggingface.co/ibm-esa-geospatial/TerraMind-1.0-small/resolve/main/TerraMind_v1_small.pt "HTTP/1.1 302 Found"
# TemporalWrapper(
#   (encoder): TerraMindViT(
#     (encoder_embeddings): ModuleDict(
#       (untok_sen2l2a@224): ImageEncoderEmbedding(
#         (proj): Linear(in_features=3072, out_features=384, bias=False)
#       )
#     )
#     (encoder): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm()
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm()
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (encoder_norm): LayerNorm()
#     (tokenizer): ModuleDict()
#   )
# )

# %% [markdown]
# ### Option 1: Temporal Wrapper — Mean Pooling
#
# We use the `TemporalWrapper` with `pooling="mean"` (the default) and enable it by passing `backbone_use_temporal=True`, which wraps the non-temporal TerraMind backbone to handle temporal inputs.
#
# With mean pooling, the model averages features across timesteps:
# - Each timestep (`t0`, `t1`, `t2`, …) is passed individually through the backbone.
# - The resulting latent representations are mean-averaged before being passed to the neck and decoder (here, a `UNetDecoder`).
#
# We set `freeze_backbone=True` for faster training; in practice, unfreezing the backbone typically improves performance.

# %%
# Option 1: Mean
model = SemanticSegmentationTask(
    model_factory="EncoderDecoderFactory",
    model_args={
        # TerraMind backbone
        "backbone": "terramind_v1_small",
        "backbone_pretrained": True,
        "backbone_modalities": ["S2L2A"],
        "backbone_bands": {"S2L2A": ["BLUE", "GREEN", "RED", "NIR_NARROW", "SWIR_1", "SWIR_2"]},

        # Apply temporal wrapper (params are passed with prefix backbone_temporal)
        "backbone_use_temporal": True,
        "backbone_temporal_pooling": "mean",  # Defaults to "mean" which also supports flexible input lengths
        
        # Necks 
        "necks": [
            {
                "name": "SelectIndices",
                "indices": [2, 5, 8, 11] # indices for terramind_v1_tiny, small, and base
                # "indices": [5, 11, 17, 23] # indices for terramind_v1_large
            },
            {
                "name": "ReshapeTokensToImage",
                "remove_cls_token": False,
            },
            {"name": "LearnedInterpolateToPyramidal"},            
        ],
        
        # Decoder
        "decoder": "UNetDecoder",
        "decoder_channels": [512, 256, 128, 64],
        
        # Head
        "head_dropout": 0.1,
        "num_classes": 13,
    },
    
    loss="ce",
    lr=1e-4, # The optimal learning rate varies between datasets, we recommend testing different once between 1e-5 and 1e-4. You can perform hyperparameter optimization using terratorch-iterate.
    optimizer="AdamW",
    ignore_index=-1,
    freeze_backbone=True,  # Speeds up fine-tuning
    freeze_decoder=False,
    plot_on_val=True,
    class_names=["Natural Vegetation", "Forest", "Corn", "Soybeans", "Wetlands", "Developed / Barren", "Open Water", "Winter Wheat", "Alfalfa", "Fallow / Idle Cropland", "Cotton", "Sorghum", "Other"],)

# %%
### Inspecting Model Pipeline with Mean Pooling

sample = train_dataset[0]
x = sample["image"].unsqueeze(0)  # [1, C, T, H, W], batch size=1

with torch.no_grad():
    feats = model.model.encoder(x)

print("Model Pipeline — Mean Pooling")
print("------------------------------")
print(f"Input shape:          {tuple(x.shape)}  [B, C, T, H, W] → Batch size 1, 6 channels, 3 timesteps")
print(f"Backbone:             {model.hparams['model_args']['backbone']}")
print(f"Temporal pooling:     {model.hparams['model_args']['backbone_temporal_pooling']}")
print(f"Encoder feature maps: {len(feats)}")
print(f"Feature map shape:  {tuple(feats[0].shape)}")

print(
    "\nThe TerraMind ViT-Small backbone returns a feature map per transformer block "
    "(12 in total), each with 196 spatial tokens and 384-dimensional embeddings."
)
print(
    "Mean pooling averages features across the 3 timesteps before they are passed "
    "into the U-Net decoder."
)

n_params_total = sum(p.numel() for p in model.parameters()) / 1e6
n_params_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad) / 1e6
print("\nModel Parameters")
print("----------------")
print(f"Total parameters:     {n_params_total:.2f}M")
print(f"Trainable (decoder):  {n_params_trainable:.2f}M")
# Out:
# Model Pipeline — Mean Pooling
# ------------------------------
# Input shape:          (1, 6, 3, 224, 224)  [B, C, T, H, W] → Batch size 1, 6 channels, 3 timesteps
# Backbone:             terramind_v1_small
# Temporal pooling:     mean
# Encoder feature maps: 12
# Feature map shape:  (1, 196, 384)
#
# The TerraMind ViT-Small backbone returns a feature map per transformer block (12 in total), each with 196 spatial tokens and 384-dimensional embeddings.
# Mean pooling averages features across the 3 timesteps before they are passed into the U-Net decoder.
#
# Model Parameters
# ----------------
# Total parameters:     31.32M
# Trainable (decoder):  9.44M

# %% [markdown]
# ### Option 2: Temporal Wrapper — Concat Pooling
#
# In this setup, the `TemporalWrapper` concatenates features from all timesteps in the latent space instead of averaging them. This increases the channel dimension by the number of timesteps (3 in this example).
#
# It is necessary to set `"n_timestamps": 3` so the model can construct the correct decoder model.
#
# Since the decoder now receives a larger input (×3 channels), this configuration results in a higher parameter count compared to mean pooling.

# %%
# Option 2: Concat
model = SemanticSegmentationTask(
    model_factory="EncoderDecoderFactory",
    model_args={
        # TerraMind backbone
        "backbone": "terramind_v1_small",
        "backbone_pretrained": True,
        "backbone_modalities": ["S2L2A"],
        "backbone_bands": {"S2L2A": ["BLUE", "GREEN", "RED", "NIR_NARROW", "SWIR_1", "SWIR_2"]},

        # Apply temporal wrapper (params are passed with prefix backbone_temporal)
        "backbone_use_temporal": True,
        "backbone_temporal_pooling": "concat",
        "backbone_temporal_n_timestamps": 3,  # Required for pooling = concat
        
        # Necks 
        "necks": [
            {
                "name": "SelectIndices",
                "indices": [2, 5, 8, 11] # indices for terramind_v1_tiny, small, and base
                # "indices": [5, 11, 17, 23] # indices for terramind_v1_large
            },
            {
                "name": "ReshapeTokensToImage",
                "remove_cls_token": False,
            },
            {"name": "LearnedInterpolateToPyramidal"},            
        ],
        
        # Decoder
        "decoder": "UNetDecoder",
        "decoder_channels": [512, 256, 128, 64],
        
        # Head
        "head_dropout": 0.1,
        "num_classes": 13,
    },
    
    loss="ce",
    lr=1e-4, # The optimal learning rate varies between datasets, we recommend testing different once between 1e-5 and 1e-4. You can perform hyperparameter optimization using terratorch-iterate.
    optimizer="AdamW",
    ignore_index=-1,
    freeze_backbone=True,  # Speeds up fine-tuning
    freeze_decoder=False,
    plot_on_val=True,
    class_names=["Natural Vegetation", "Forest", "Corn", "Soybeans", "Wetlands", "Developed / Barren", "Open Water", "Winter Wheat", "Alfalfa", "Fallow / Idle Cropland", "Cotton", "Sorghum", "Other"],)

# %%
### Inspecting Model Pipeline with Concat Pooling

model.eval()
sample = train_dataset[0]
x = sample["image"].unsqueeze(0)  # [1, C, T, H, W], batch size=1

with torch.no_grad():
    feats = model.model.encoder(x)

print("Model Pipeline — Concat Pooling")
print("-------------------------------")
print(f"Input shape:          {tuple(x.shape)}  [B, C, T, H, W] → Batch size 1, 6 channels, 3 timesteps")
print(f"Backbone:             {model.hparams['model_args']['backbone']}")
print(f"Temporal pooling:     {model.hparams['model_args']['backbone_temporal_pooling']}")
print(f"Encoder feature maps: {len(feats)}")
print(f"Example feature map:  {tuple(feats[0].shape)}")

print(
    "\nThe TerraMind ViT-Small backbone returns a feature map per transformer "
    "block (12 total), each with 196 spatial tokens and 384-dimensional embeddings."
)
print(
    "Concat pooling stacks the features from all 3 timesteps along the channel "
    "dimension (now 1152-dim) before passing them to the U-Net decoder, increasing the decoder’s "
    "input size and number of parameters."
)

n_params_total = sum(p.numel() for p in model.parameters()) / 1e6
n_params_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad) / 1e6
print("\nModel Parameters")
print("----------------")
print(f"Total parameters:     {n_params_total:.2f}M")
print(f"Trainable (decoder):  {n_params_trainable:.2f}M")
# Out:
# Model Pipeline — Concat Pooling
# -------------------------------
# Input shape:          (1, 6, 3, 224, 224)  [B, C, T, H, W] → Batch size 1, 6 channels, 3 timesteps
# Backbone:             terramind_v1_small
# Temporal pooling:     concat
# Encoder feature maps: 12
# Example feature map:  (1, 196, 1152)
#
# The TerraMind ViT-Small backbone returns a feature map per transformer block (12 total), each with 196 spatial tokens and 384-dimensional embeddings.
# Concat pooling stacks the features from all 3 timesteps along the channel dimension (now 1152-dim) before passing them to the U-Net decoder, increasing the decoder’s input size and number of parameters.
#
# Model Parameters
# ----------------
# Total parameters:     44.81M
# Trainable (decoder):  22.94M

# %% [markdown]
# ### Option 3: Temporal Wrapper — Diff with Subset Averaging
#
# This mode computes the difference between two temporal elements. If `subset_lengths` is
# provided, the wrapper first averages within each defined subset before applying the
# difference. For example, with three timesteps and `subset_lengths=[1, 2]`, the first
# timestep (`t₀`) forms the first subset and the remaining two (`t₁`, `t₂`) form the
# second. The wrapper returns the difference between the two subset means.
#
# After differencing, the representation retains the same shape as a single timestep,
# so decoder input size and total parameter count remain unchanged compared to mean pooling.

# %%
# Option 3: Diff with Subset Averaging

model = SemanticSegmentationTask(
    model_factory="EncoderDecoderFactory",
    model_args={
        # TerraMind backbone
        "backbone": "terramind_v1_small",
        "backbone_pretrained": True,
        "backbone_modalities": ["S2L2A"],
        "backbone_bands": {"S2L2A": ["BLUE", "GREEN", "RED", "NIR_NARROW", "SWIR_1", "SWIR_2"]},

        # Apply temporal wrapper (params are passed with prefix backbone_temporal)
        "backbone_use_temporal": True,
        "backbone_temporal_pooling": "diff",
        "backbone_temporal_subset_lengths": [1, 2],  # First timestep vs mean of timesteps 2–3

        
        # Necks 
        "necks": [
            {
                "name": "SelectIndices",
                "indices": [2, 5, 8, 11] # indices for terramind_v1_tiny, small, and base
                # "indices": [5, 11, 17, 23] # indices for terramind_v1_large
            },
            {
                "name": "ReshapeTokensToImage",
                "remove_cls_token": False,
            },
            {"name": "LearnedInterpolateToPyramidal"},            
        ],
        
        # Decoder
        "decoder": "UNetDecoder",
        "decoder_channels": [512, 256, 128, 64],
        
        # Head
        "head_dropout": 0.1,
        "num_classes": 13,
    },
    
    loss="ce",
    lr=1e-4, # The optimal learning rate varies between datasets, we recommend testing different once between 1e-5 and 1e-4. You can perform hyperparameter optimization using terratorch-iterate.
    optimizer="AdamW",
    ignore_index=-1,
    freeze_backbone=True,  # Speeds up fine-tuning
    freeze_decoder=False,
    plot_on_val=True,
    class_names=["Natural Vegetation", "Forest", "Corn", "Soybeans", "Wetlands", "Developed / Barren", "Open Water", "Winter Wheat", "Alfalfa", "Fallow / Idle Cropland", "Cotton", "Sorghum", "Other"],)

# %%
### Inspecting Model Pipeline with Diff Subsets Pooling

model.eval()
sample = train_dataset[0]
x = sample["image"].unsqueeze(0)  # [1, C, T, H, W]

with torch.no_grad():
    feats = model.model.encoder(x)

print("Model Pipeline — Diff Subsets Pooling")
print("--------------------------------------")
print(f"Input shape:          {tuple(x.shape)}  [B, C, T, H, W] → Batch size 1, 6 channels, 3 timesteps")
print(f"Backbone:             {model.hparams['model_args']['backbone']}")
print(f"Temporal pooling:     {model.hparams['model_args']['backbone_temporal_pooling']}")
print(f"Encoder feature maps: {len(feats)}")
print(f"Example feature map:  {tuple(feats[0].shape)}")

print(
    "\nThe 12 intermediate layers of the TerraMind ViT-Small backbone each produce "
    "a feature map of 196 tokens with 384 dimensions."
)
print(
    "Diff subsets pooling computes the difference between the mean of two temporal subsets"
    " and returns a single feature representation with the same shape as a single timestep."
    "This keeps the decoder size and parameter count identical to mean pooling."
)


n_params_total = sum(p.numel() for p in model.parameters()) / 1e6
n_params_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad) / 1e6
print("\nModel Parameters")
print("----------------")
print(f"Total parameters:     {n_params_total:.2f}M")
print(f"Trainable (decoder):  {n_params_trainable:.2f}M")
# Out:
# Model Pipeline — Diff Subsets Pooling
# --------------------------------------
# Input shape:          (1, 6, 3, 224, 224)  [B, C, T, H, W] → Batch size 1, 6 channels, 3 timesteps
# Backbone:             terramind_v1_small
# Temporal pooling:     diff
# Encoder feature maps: 12
# Example feature map:  (1, 196, 384)
#
# The 12 intermediate layers of the TerraMind ViT-Small backbone each produce a feature map of 196 tokens with 384 dimensions.
# Diff subsets pooling computes the difference between the mean of two temporal subsets and returns a single feature representation with the same shape as a single timestep.This keeps the decoder size and parameter count identical to mean pooling.
#
# Model Parameters
# ----------------
# Total parameters:     31.32M
# Trainable (decoder):  9.44M

# %% [markdown]
# ## Training
#
# The constructed encoder–decoder pipelines and wrapped backbones can be trained in the same way as single-timestep or non-wrapped models.

# %%
pl.seed_everything(0)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    dirpath="output/terramind_base_multicrop/checkpoints/",
    mode="min",
    monitor="val/loss",
    filename="best-loss",
    save_weights_only=True,
)

# Lightning Trainer
trainer = pl.Trainer(
    accelerator="auto",
    strategy="auto",
    devices=1, # Lightning multi-gpu often fails in notebooks
    precision='bf16-mixed',  # Speed up training
    num_nodes=1,
    logger=True, # Uses TensorBoard by default
    max_epochs=3, # For demo notebooks
    log_every_n_steps=1,
    callbacks=[checkpoint_callback, pl.callbacks.RichProgressBar()],
    default_root_dir="output/terramind_base_multicrop",
)
# Out:
# Seed set to 0
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores

# %%
# Training -> Check out other tutorials for more details on training and evaluating TerraTorch models
trainer.fit(model, datamodule=datamodule)
# Out:
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ PixelWiseModel   │ 31.3 M │ eval │     0 │
# │ 1 │ criterion     │ CrossEntropyLoss │      0 │ eval │     0 │
# │ 2 │ train_metrics │ MetricCollection │      0 │ eval │     0 │
# │ 3 │ val_metrics   │ MetricCollection │      0 │ eval │     0 │
# │ 4 │ test_metrics  │ ModuleList       │      0 │ eval │     0 │
# └───┴───────────────┴──────────────────┴────────┴──────┴───────┘
# Trainable params: 9.4 M
# Non-trainable params: 21.9 M
# Total params: 31.3 M
# Total estimated model params size (MB): 125
# Modules in train mode: 0
# Modules in eval mode: 289
# Total FLOPs: 0
# Output()
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:630, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     624 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     625     self.state.fn,
#     626     ckpt_path,
#     627     model_provided=True,
#     628     model_connected=self.lightning_module is not None,
#     629 )
# --> 630 self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     632 assert self.state.stopped
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:1079, in Trainer._run(self, model, ckpt_path, weights_only)
#    1076 # ----------------------------
#    1077 # RUN THE TRAINER
#    1078 # ----------------------------
# -> 1079 results = self._run_stage()
#    1081 # ----------------------------
#    1082 # POST-Training CLEAN UP
#    1083 # ----------------------------
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:1123, in Trainer._run_stage(self)
#    1122 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1123     self.fit_loop.run()
#    1124 return None
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:217, in _FitLoop.run(self)
#     216 self.on_advance_start()
# --> 217 self.advance()
#     218 self.on_advance_end()
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:465, in _FitLoop.advance(self)
#     464 assert self._data_fetcher is not None
# --> 465 self.epoch_loop.run(self._data_fetcher)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/training_epoch_loop.py:153, in _TrainingEpochLoop.run(self, data_fetcher)
#     152 try:
# --> 153     self.advance(data_fetcher)
#     154     self.on_advance_end(data_fetcher)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/training_epoch_loop.py:352, in _TrainingEpochLoop.advance(self, data_fetcher)
#     350 if trainer.lightning_module.automatic_optimization:
#     351     # in automatic optimization, there can only be one optimizer
# --> 352     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     353 else:
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py:192, in _AutomaticOptimization.run(self, optimizer, batch_idx, kwargs)
#     187 # ------------------------------
#     188 # BACKWARD PASS
#     189 # ------------------------------
#     190 # gradient update with accumulated gradients
#     191 else:
# --> 192     self._optimizer_step(batch_idx, closure)
#     194 result = closure.consume_result()
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py:270, in _AutomaticOptimization._optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     269 # model hook
# --> 270 call._call_lightning_module_hook(
#     271     trainer,
#     272     "optimizer_step",
#     273     trainer.current_epoch,
#     274     batch_idx,
#     275     optimizer,
#     276     train_step_and_backward_closure,
#     277 )
#     279 if not should_accumulate:
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:177, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     176 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 177     output = fn(*args, **kwargs)
#     179 # restore current_fx when nested context
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/core/module.py:1368, in LightningModule.optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1344 r"""Override this method to adjust the default way the :class:`~lightning.pytorch.trainer.trainer.Trainer` calls
#    1345 the optimizer.
#    1346
#    (...)
#    1366
#    1367 """
# -> 1368 optimizer.step(closure=optimizer_closure)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/core/optimizer.py:154, in LightningOptimizer.step(self, closure, **kwargs)
#     153 assert self._strategy is not None
# --> 154 step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     156 self._on_after_step()
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/strategies/strategy.py:239, in Strategy.optimizer_step(self, optimizer, closure, model, **kwargs)
#     238 assert isinstance(model, pl.LightningModule)
# --> 239 return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/plugins/precision/amp.py:76, in MixedPrecision.optimizer_step(self, optimizer, model, closure, **kwargs)
#      74 if self.scaler is None:
#      75     # skip scaler logic, as bfloat16 does not require scaler
# ---> 76     return super().optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#      77 if isinstance(optimizer, LBFGS):
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/plugins/precision/precision.py:123, in Precision.optimizer_step(self, optimizer, model, closure, **kwargs)
#     122 closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 123 return optimizer.step(closure=closure, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/optim/optimizer.py:485, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     481             raise RuntimeError(
#     482                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     483             )
# --> 485 out = func(*args, **kwargs)
#     486 self._optimizer_step_code()
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/optim/optimizer.py:79, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      78     torch._dynamo.graph_break()
# ---> 79     ret = func(self, *args, **kwargs)
#      80 finally:
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/optim/adam.py:225, in Adam.step(self, closure)
#     224     with torch.enable_grad():
# --> 225         loss = closure()
#     227 for group in self.param_groups:
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/plugins/precision/precision.py:109, in Precision._wrap_closure(self, model, optimizer, closure)
#     102 """This double-closure allows makes sure the ``closure`` is executed before the ``on_before_optimizer_step``
#     103 hook is called.
#     104
#    (...)
#     107
#     108 """
# --> 109 closure_result = closure()
#     110 self._after_closure(model, optimizer)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py:146, in Closure.__call__(self, *args, **kwargs)
#     144 @override
#     145 def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 146     self._result = self.closure(*args, **kwargs)
#     147     return self._result.loss
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     115 with ctx_factory():
# --> 116     return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py:131, in Closure.closure(self, *args, **kwargs)
#     128 @override
#     129 @torch.enable_grad()
#     130 def closure(self, *args: Any, **kwargs: Any) -> ClosureResult:
# --> 131     step_output = self._step_fn()
#     133     if step_output.closure_loss is None:
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py:319, in _AutomaticOptimization._training_step(self, kwargs)
#     317 trainer = self.trainer
# --> 319 training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#     320 self.trainer.strategy.post_training_step()  # unused hook - call anyway for backward compatibility
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:329, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     328 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 329     output = fn(*args, **kwargs)
#     331 # restore current_fx when nested context
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/strategies/strategy.py:391, in Strategy.training_step(self, *args, **kwargs)
#     390     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
# --> 391 return self.lightning_module.training_step(*args, **kwargs)
#
# File ~/Documents/1_Embed2Scale/Embedding_Benchmarking/terratorch/terratorch/tasks/segmentation_tasks.py:340, in SemanticSegmentationTask.training_step(self, batch, batch_idx, dataloader_idx)
#     339 y_hat_hard = to_segmentation_prediction(model_output)
# --> 340 self.train_metrics.update(y_hat_hard, y)
#     342 return loss["loss"]
#
# File ~/miniconda3/lib/python3.13/site-packages/torchmetrics/collections.py:254, in MetricCollection.update(self, *args, **kwargs)
#     253     m0 = getattr(self, cg[0])
# --> 254     m0.update(*args, **m0._filter_kwargs(**kwargs))
#     255 self._state_is_copy = False
#
# File ~/miniconda3/lib/python3.13/site-packages/torchmetrics/wrappers/classwise.py:173, in ClasswiseWrapper.update(self, *args, **kwargs)
#     172 """Update state."""
# --> 173 self.metric.update(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/torchmetrics/metric.py:549, in Metric._wrap_update.<locals>.wrapped_func(*args, **kwargs)
#     548 try:
# --> 549     update(*args, **kwargs)
#     550 except RuntimeError as err:
#
# File ~/miniconda3/lib/python3.13/site-packages/torchmetrics/classification/confusion_matrix.py:283, in MulticlassConfusionMatrix.update(self, preds, target)
#     282 if self.validate_args:
# --> 283     _multiclass_confusion_matrix_tensor_validation(preds, target, self.num_classes, self.ignore_index)
#     284 preds, target = _multiclass_confusion_matrix_format(preds, target, self.ignore_index)
#
# File ~/miniconda3/lib/python3.13/site-packages/torchmetrics/functional/classification/confusion_matrix.py:289, in _multiclass_confusion_matrix_tensor_validation(preds, target, num_classes, ignore_index)
#     288 for t, name in ((target, "target"),) + ((preds, "preds"),) if not preds.is_floating_point() else ():  # noqa: RUF005
# --> 289     num_unique_values = len(torch.unique(t, dim=None))
#     290     if num_unique_values > check_value:
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/_jit_internal.py:622, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     621 else:
# --> 622     return if_false(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/_jit_internal.py:622, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     621 else:
# --> 622     return if_false(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/functional.py:1102, in _return_output(input, sorted, return_inverse, return_counts, dim)
#    1100     return _unique_impl(input, sorted, return_inverse, return_counts, dim)
# -> 1102 output, _, _ = _unique_impl(input, sorted, return_inverse, return_counts, dim)
#    1103 return output
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/functional.py:995, in _unique_impl(input, sorted, return_inverse, return_counts, dim)
#     994 else:
# --> 995     output, inverse_indices, counts = torch._unique2(
#     996         input,
#     997         sorted=sorted,
#     998         return_inverse=return_inverse,
#     999         return_counts=return_counts,
#    1000     )
#    1001 return output, inverse_indices, counts
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[16], line 2
#       1 # Training -> Check out other tutorials for more details on training and evaluating TerraTorch models
# ----> 2 trainer.fit(model, datamodule=datamodule)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:584, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     583 self.should_stop = False
# --> 584 call._call_and_handle_interrupt(
#     585     self,
#     586     self._fit_impl,
#     587     model,
#     588     train_dataloaders,
#     589     val_dataloaders,
#     590     datamodule,
#     591     ckpt_path,
#     592     weights_only,
#     593 )
#
# File ~/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:66, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      65         launcher.kill(_get_sigkill_signal())
# ---> 66     sys.exit(1)
#      68 except BaseException as exception:
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# ## Training via CLI
#
# Above, we introduced the required TerraTorch components and how to combine them flexibly. The same workflow can be run in a no-code setup by configuring all components in a YAML file and executing it via the PyTorch Lightning CLI.
#
# We provide a sample YAML that reproduces the workflow above and serves as a starting point for similar pipelines.
#
# **Note:** You may want to restart the session to free up memory before running the CLI workflow.

# %%
# Run fine-tuning
# !terratorch fit -c temporalwrapper_segementation_crop.yaml
# Out:
# Seed set to 42
# 2025-12-22 11:01:17,506 - INFO - HTTP Request: HEAD https://huggingface.co/ibm-esa-geospatial/TerraMind-1.0-small/resolve/main/TerraMind_v1_small.pt "HTTP/1.1 302 Found"
# 2025-12-22 11:01:17,619 - INFO - Loaded weights for BLUE in position 0 of patch embed
# 2025-12-22 11:01:17,619 - INFO - Loaded weights for GREEN in position 1 of patch embed
# 2025-12-22 11:01:17,620 - INFO - Loaded weights for RED in position 2 of patch embed
# 2025-12-22 11:01:17,620 - INFO - Loaded weights for NIR_NARROW in position 3 of patch embed
# 2025-12-22 11:01:17,620 - INFO - Loaded weights for SWIR_1 in position 4 of patch embed
# 2025-12-22 11:01:17,620 - INFO - Loaded weights for SWIR_2 in position 5 of patch embed
# /Users/isw/miniconda3/lib/python3.13/site-packages/lightning/pytorch/cli.py:734: `SemanticSegmentationTask.configure_optimizers` will be overridden by `MyLightningCLI.configure_optimizers`.
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# /Users/isw/miniconda3/lib/python3.13/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ PixelWiseModel   │ 31.3 M │ train │     0 │
# │ 1 │ criterion     │ CrossEntropyLoss │      0 │ train │     0 │
# │ 2 │ train_metrics │ MetricCollection │      0 │ train │     0 │
# │ 3 │ val_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 4 │ test_metrics  │ ModuleList       │      0 │ train │     0 │
# └───┴───────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 31.3 M
# Non-trainable params: 0
# Total params: 31.3 M
# Total estimated model params size (MB): 125
# Modules in train mode: 289
# Modules in eval mode: 0
# Total FLOPs: 0
# /Users/isw/miniconda3/lib/python3.13/site-packages/lightning/pytorch/trainer/con
# nectors/data_connector.py:429: Consider setting `persistent_workers=True` in
# 'val_dataloader' to speed up the dataloader worker initialization.
